# %%
### import the required packages to the notebook
import pandas as pd
import os

# %%
### Get the current working drectory
print(os.getcwd()) ## Where your python is expectiong your files
os.chdir("C:\\Users\\vatsal\\Documents\\Upgrad\\Session 2") ## Where you want your file
print(os.getcwd())
# Out:
# C:\Users\vatsal\Documents
# C:\Users\vatsal\Documents\Upgrad\Session 2

# %%
## print all the files present in current working directory
os.listdir()
# Out:
# ['Custom Office Templates',
#  'desktop.ini',
#  'Downloads',
#  'Elder Scrolls Online',
#  'IPMsg',
#  'My Games',
#  'My Music',
#  'My Pictures',
#  'My Videos',
#  'Sound recordings',
#  'Upgrad',
#  'Visual Studio 2017',
#  'Zoom']

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#     Read a comma-separated values (csv) file into DataFrame.
#
# ...

# %%
### lets read the csv first
sales = pd.read_csv('SalesKaggle3.csv') #### CREATING DATAFRAME FROM CSV
## Link to all encoding allowed in python : https://docs.python.org/3/library/codecs.html#standard-encodings

### Try different encoding to read the file -- when you get unicode decode type error 
#sales = pd.read_csv('./Upgrad/Session 2/SalesKaggle3.csv', encoding='ISO-8859-2')

# %%
#Viewing some top rows from the file
sales.head(2)
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# 1         39          0.00        15.54

# %%
### print the various statistics about data
print("shape of data is :", sales.shape)
print ("Name of columns are :",sales.columns)
print ("Index of data is :",sales.index)
# Out:
# shape of data is : (198917, 14)
# Name of columns are : Index(['Order', 'File_Type', 'SKU_number', 'SoldFlag', 'SoldCount',
#        'MarketingType', 'ReleaseNumber', 'New_Release_Flag', 'StrengthFactor',
#        'PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice'],
#       dtype='object')
# Index of data is : RangeIndex(start=0, stop=198917, step=1)

# %%
### Lets describe the data first before anything
sales.describe()
### does not include object data types
# Out:
#                Order    SKU_number      SoldFlag     SoldCount  ReleaseNumber  \
# count  198917.000000  1.989170e+05  75996.000000  75996.000000  198917.000000
# mean   106483.543242  8.613626e+05      0.171009      0.322306       3.412202
# std     60136.716784  8.699794e+05      0.376519      1.168615       3.864243
# min         2.000000  5.000100e+04      0.000000      0.000000       0.000000
# 25%     55665.000000  2.172520e+05      0.000000      0.000000       1.000000
# 50%    108569.000000  6.122080e+05      0.000000      0.000000       2.000000
# 75%    158298.000000  9.047510e+05      0.000000      0.000000       5.000000
# max    208027.000000  3.960788e+06      1.000000     73.000000      99.000000
#
#        New_Release_Flag  StrengthFactor       PriceReg    ReleaseYear  \
# count     198917.000000    1.989170e+05  198917.000000  198917.000000
# mean           0.642248    1.117115e+06      90.895243    2006.016414
# ...

# %%
sales.dtypes
# Out:
# Order                 int64
# File_Type            object
# SKU_number            int64
# SoldFlag            float64
# SoldCount           float64
# MarketingType        object
# ReleaseNumber         int64
# New_Release_Flag      int64
# StrengthFactor      float64
# PriceReg            float64
# ReleaseYear           int64
# ItemCount             int64
# LowUserPrice        float64
# LowNetPrice         float64
# dtype: object

# %%
sales.describe(include = ['object','int64'] )
# Out:
#                 Order File_Type    SKU_number MarketingType  ReleaseNumber  \
# count   198917.000000    198917  1.989170e+05        198917  198917.000000
# unique            NaN         2           NaN             2            NaN
# top               NaN    Active           NaN             S            NaN
# freq              NaN    122921           NaN        100946            NaN
# mean    106483.543242       NaN  8.613626e+05           NaN       3.412202
# std      60136.716784       NaN  8.699794e+05           NaN       3.864243
# min          2.000000       NaN  5.000100e+04           NaN       0.000000
# 25%      55665.000000       NaN  2.172520e+05           NaN       1.000000
# 50%     108569.000000       NaN  6.122080e+05           NaN       2.000000
# 75%     158298.000000       NaN  9.047510e+05           NaN       5.000000
# max     208027.000000       NaN  3.960788e+06           NaN      99.000000
#
#         New_Release_Flag    ReleaseYear      ItemCount
# ...

# %% [markdown]
# For numeric data, the result’s index will include count, mean, std, min, max as well as lower, 50 and upper percentiles. By default the lower percentile is 25 and the upper percentile is 75. The 50 percentile is the same as the median.
#
# For object data (e.g. strings or timestamps), the result’s index will include count, unique, top, and freq. The top is the most common value. The freq is the most common value’s frequency. Timestamps also include the first and last items.

# %%
## Now we have some idea about data lets udnerstand subsetting the data using Location
.loc
.iloc
.ix [deprecated] - complex
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %% [markdown]
# ## Subsetting the data using Location

# %%
test1 = sales.iloc[0:4,[3,7]]
print (test1)
type(test1)
# Out:
#    SoldFlag  New_Release_Flag
# 0       0.0                 1
# 1       0.0                 1
# 2       0.0                 0
# 3       1.0                 1
# pandas.core.frame.DataFrame

# %%
test2 = sales.iloc[0:3,3]
print (test2)
type(test2)
# Out:
# 0    0.0
# 1    0.0
# 2    0.0
# Name: SoldFlag, dtype: float64
# pandas.core.series.Series

# %% [markdown]
# One Gotcha : If you select only one column you will get Series data
# Workaround : Pass the columns in a list to get a dataframe

# %% [markdown]
# ### Subsetting the data using Index

# %%
test3 = sales.loc[0:5,'SoldFlag']
print (test3)
type(test3)
# Out:
# 0    0.0
# 1    0.0
# 2    0.0
# 3    1.0
# 4    1.0
# 5    0.0
# Name: SoldFlag, dtype: float64
# pandas.core.series.Series

# %% [markdown]
# Indexing a using Dataframe.ix[ ] :
# Early in the development of pandas, there existed another indexer, ix. This indexer was capable of selecting both by label and by integer location. While it was versatile, it caused lots of confusion because it’s not explicit. Sometimes integers can also be labels for rows or columns. Thus there were instances where it was ambiguous. Generally, ix is label based and acts just as the .loc indexer. However, .ix also supports integer type selections (as in .iloc) where passed an integer. This only works where the index of the DataFrame is not integer based .ix will accept any of the inputs of .loc and .iloc.
# Note: The .ix indexer has been deprecated in recent versions of Pandas.

# %%
sales.head(5)
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %%
#sales.loc[sales['File_Type'] == 'Active', :]
(sales['MarketingType'] =='D')
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21         True
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29         True
#           ...
# 198887    False
# 198888     True
# 198889    False
# 198890    False
# 198891    False
# 198892    False
# 198893     True
# 198894    False
# 198895     True
# 198896     True
# 198897     True
# 198898    False
# 198899    False
# 198900    False
# 198901    False
# 198902    False
# 198903    False
# 198904    False
# 198905     True
# 198906     True
# 198907     True
# 198908    False
# 198909    False
# 198910    False
# ...

# %% [markdown]
# ### Subsetting based on a condition

# %%
### select rows where birthplace is new y ork 
sales.loc[~(sales['MarketingType'] =='D') & (sales['SoldFlag'] == 1), :].head(5)
# Out:
#        Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 35119  35917  Historical      525973       1.0        1.0             S
# 35138  35939  Historical      112110       1.0        1.0             S
# 35139  35940  Historical      114004       1.0        1.0             S
# 35153  35990  Historical      200702       1.0        1.0             S
# 35154  35994  Historical     2105393       1.0        1.0             S
#
#        ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 35119             13                 1        159212.0    121.95         2010
# 35138              3                 1        850198.0    124.50         2000
# 35139              3                 1         32882.0     62.20         1999
# 35153              2                 1        271247.0    105.75         2007
# 35154              0                 0        702017.0     49.00         2014
#
#        ItemCount  LowUserPrice  LowNetPrice
# ...

# %%
### select rows where birthplace is new york and _unit state is golded
#sales[(sales['ReleaseNumber']== 13) | (sales['ReleaseYear'] == 2010)].head(50)

# %% [markdown]
# ### Understanding group by in python
#
# The core syntax can be broken down similar to the Select-From-Groupby-Where clause. Sample code is given below :
#
# Table_name.groupby(['Group'])['Feature'].aggregation()
#
# Table_name to specify the FROM
# 'Group' is the list of GROUP BY variables
# 'Feature' is the list of SELECT variables (with or without WHERE condition)
# Aggregate() is to specify the aggregation

# %%
#Two step query to find oscars by birthlace
sales_year = sales.groupby(['ReleaseYear'])
sales_order = sales_year['Order'].count()
print(sales_order)
print(type(sales_order))
# Out:
# ReleaseYear
# 0           1
# 1900      338
# 1904        2
# 1905        1
# 1914        1
# 1922        2
# 1923        1
# 1927        1
# 1931        2
# 1932        1
# 1935        3
# 1941        1
# 1945        2
# 1946        1
# 1948        2
# 1949        1
# 1950        4
# 1951        3
# 1952        8
# 1953        4
# 1954        8
# 1955       10
# 1956       12
# 1957        9
# 1958       12
# 1959       12
# 1960       18
# 1961       15
# 1962       22
# 1963       28
#         ...
# 1989      581
# 1990      687
# 1991      965
# 1992     1021
# 1993     1299
# 1994     1561
# 1995     1939
# 1996     2407
# 1997     2885
# 1998     3172
# 1999     3869
# 2000     4775
# 2001     5831
# 2002     6659
# 2003     8683
# 2004    10093
# 2005    11713
# 2006    12881
# 2007    14503
# 2008    14822
# 2009    14792
# 2010    15683
# 2011    14699
# 2012    13473
# 2013    11402
# 2014     8916
# 2015     4313
# 2016      701
# 2017        7
# 2018        1
# ...

# %%
#Alternate way of writing
sales.groupby(['ReleaseYear'])['Order'].count()
# Out:
# ReleaseYear
# 0           1
# 1900      338
# 1904        2
# 1905        1
# 1914        1
# 1922        2
# 1923        1
# 1927        1
# 1931        2
# 1932        1
# 1935        3
# 1941        1
# 1945        2
# 1946        1
# 1948        2
# 1949        1
# 1950        4
# 1951        3
# 1952        8
# 1953        4
# 1954        8
# 1955       10
# 1956       12
# 1957        9
# 1958       12
# 1959       12
# 1960       18
# 1961       15
# 1962       22
# 1963       28
#         ...
# 1989      581
# 1990      687
# 1991      965
# 1992     1021
# 1993     1299
# 1994     1561
# 1995     1939
# 1996     2407
# 1997     2885
# 1998     3172
# 1999     3869
# 2000     4775
# 2001     5831
# 2002     6659
# 2003     8683
# 2004    10093
# 2005    11713
# 2006    12881
# 2007    14503
# 2008    14822
# 2009    14792
# 2010    15683
# 2011    14699
# 2012    13473
# 2013    11402
# 2014     8916
# 2015     4313
# 2016      701
# 2017        7
# 2018        1
# ...

# %%
### Adding more levels
type(sales.groupby(['ReleaseYear'])['Order', 'MarketingType'].count())
sales.groupby(['ReleaseYear'])['Order', 'MarketingType'].count().sort_values('Order', ascending = False)[0:5]


#Can we do a sum here?
# Out:
#              Order  MarketingType
# ReleaseYear
# 2010         15683          15683
# 2008         14822          14822
# 2009         14792          14792
# 2011         14699          14699
# 2007         14503          14503

# %%
sales.head(2)
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# 1         39          0.00        15.54

# %%
#How many houses were sold by year and MarketType and thier value
sales_agg = sales.groupby(['ReleaseYear', 'MarketingType']).agg({'Order':'count','LowNetPrice': 'sum', 'PriceReg': 'mean'})

# %%
##Some major problem here
sales_agg.head(10)
#print(sales_agg.head(10))
#sales_agg.index
# Out:
#    ReleaseYear MarketingType  Order  LowNetPrice    PriceReg
# 0            0             D      1        44.02   68.990000
# 1         1900             D    203     11305.42   62.674433
# 2         1900             S    135      7191.23   83.595778
# 3         1904             D      2       163.11   84.185000
# 4         1905             D      1        60.37   60.370000
# 5         1914             S      1         0.00   26.000000
# 6         1922             S      2        47.99  114.975000
# 7         1923             D      1        46.94   76.000000
# 8         1927             D      1       103.99  100.000000
# 9         1931             D      1        19.36   26.000000

# %%
#Reset Index
sales_agg.reset_index(['ReleaseYear', 'MarketingType'], inplace = True)

# %%
sales.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# ...

# %%
### Joining - left join, inner join and outer join -- pd.merge
print (sales_agg.shape)
print(sales.shape)
print(sales_agg.columns)
print(sales.columns)
merge1 = pd.merge(sales,sales_agg,on = ['ReleaseYear', 'MarketingType'],how = 'left', suffixes  = ['', '_agg'])
type(merge1)
# Out:
# (154, 5)
# (198917, 14)
# Index(['ReleaseYear', 'MarketingType', 'Order', 'LowNetPrice', 'PriceReg'], dtype='object')
# Index(['Order', 'File_Type', 'SKU_number', 'SoldFlag', 'SoldCount',
#        'MarketingType', 'ReleaseNumber', 'New_Release_Flag', 'StrengthFactor',
#        'PriceReg', 'ReleaseYear', 'ItemCount', 'LowUserPrice', 'LowNetPrice'],
#       dtype='object')
# pandas.core.frame.DataFrame

# %%
merge1['Percent_value'] = (merge1['LowUserPrice'] / merge1['LowNetPrice_agg'])*100

# %%
# merge1.head()

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
#     Merge DataFrame objects by performing a database-style join operation by
#     columns or indexes.
#
#     If joining columns on columns, the DataFrame indexes *will be
#     ignored*. Otherwise if joining indexes on indexes or indexes on a column or
#     columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order
#         * right: use only keys from right frame, similar to a SQL right outer join;
#           preserve key order
# ...

# %%
#Dealing with missing values
import numpy as np
sales.isnull()
np.sum(sales.isnull(), axis = 0)
# Out:
# Order               0
# File_Type           0
# SKU_number          0
# SoldFlag            0
# SoldCount           0
# MarketingType       0
# ReleaseNumber       0
# New_Release_Flag    0
# StrengthFactor      0
# PriceReg            0
# ReleaseYear         0
# ItemCount           0
# LowUserPrice        0
# LowNetPrice         0
# dtype: int64

# %%
for col in sales.columns:
    print(col)
    sales[col].fillna(0,inplace = True)
# Out:
# Order
# File_Type
# SKU_number
# SoldFlag
# SoldCount
# MarketingType
# ReleaseNumber
# New_Release_Flag
# StrengthFactor
# PriceReg
# ReleaseYear
# ItemCount
# LowUserPrice
# LowNetPrice

# %%
sales = sales.fillna('Unknown')

# %%
sales_agg.head()
# Out:
#    ReleaseYear MarketingType  Order  LowNetPrice   PriceReg
# 0            0             D      1        44.02  68.990000
# 1         1900             D    203     11305.42  62.674433
# 2         1900             S    135      7191.23  83.595778
# 3         1904             D      2       163.11  84.185000
# 4         1905             D      1        60.37  60.370000

# %%
#Changing between rows and columns
sales_agg.pivot_table(index = 'ReleaseYear', columns = 'MarketingType', values = 'Order', aggfunc = 'sum').fillna(0)
#sales_agg.pivot_table(index = 'ReleaseYear', columns = 'Order', values = 'MarketingType', aggfunc = 'sum')
# Out:
# MarketingType       D       S
# ReleaseYear
# 0                 1.0     0.0
# 1900            203.0   135.0
# 1904              2.0     0.0
# 1905              1.0     0.0
# 1914              0.0     1.0
# 1922              0.0     2.0
# 1923              1.0     0.0
# 1927              1.0     0.0
# 1931              1.0     1.0
# 1932              0.0     1.0
# 1935              2.0     1.0
# 1941              1.0     0.0
# 1945              0.0     2.0
# 1946              1.0     0.0
# 1948              2.0     0.0
# 1949              1.0     0.0
# 1950              4.0     0.0
# 1951              1.0     2.0
# 1952              5.0     3.0
# 1953              4.0     0.0
# 1954              6.0     2.0
# 1955              7.0     3.0
# 1956             10.0     2.0
# 1957              8.0     1.0
# 1958             10.0     2.0
# 1959              9.0     3.0
# 1960             12.0     6.0
# 1961             13.0     2.0
# 1962             15.0     7.0
# ...

# %%
help(pd.pivot_table)
# Out:
# Help on function pivot_table in module pandas.core.reshape.pivot:
#
# pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All')
#     Create a spreadsheet-style pivot table as a DataFrame. The levels in
#     the pivot table will be stored in MultiIndex objects (hierarchical
#     indexes) on the index and columns of the result DataFrame.
#
#     Parameters
#     ----------
#     data : DataFrame
#     values : column to aggregate, optional
#     index : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
#         list can contain any of the other types (except list).
#         Keys to group by on the pivot table index.  If an array is passed,
#         it is being used as the same manner as column values.
#     columns : column, Grouper, array, or list of the previous
# ...

# %% [markdown]
# # Visualizations

# %%
import matplotlib
from matplotlib import pyplot as plt

# %matplotlib inline
matplotlib.style.use('ggplot')

# %%
pricereg_year =sales_agg.groupby(['ReleaseYear'])['PriceReg'].mean()

# %%
pricereg_year = pricereg_year.reset_index()
pricereg_year = pricereg_year.loc[pricereg_year['ReleaseYear'] > 2000,:]

# %%
pricereg_year
# Out:
#     ReleaseYear    PriceReg
# 67         2001   91.802409
# 68         2002   92.562668
# 69         2003   93.409946
# 70         2004   95.628880
# 71         2005   93.495152
# 72         2006   96.431859
# 73         2007   94.411967
# 74         2008   93.525357
# 75         2009   90.874851
# 76         2010   95.806287
# 77         2011   98.117979
# 78         2012  103.086738
# 79         2013  100.098192
# 80         2014   85.097016
# 81         2015   79.353005
# 82         2016   79.872859
# 83         2017   62.645000
# 84         2018   92.820000

# %%
###############Line charts - Trends - best to show something with a linear relation
plt.figure(figsize = (10,10))
plt.xlabel("Year", fontsize = 10)
plt.ylabel("Price", fontsize = 10)
plt.title("Price Over the Years")
#####plt.plot(x, y)
plt.plot(pricereg_year['ReleaseYear'], pricereg_year['PriceReg'])
plt.plot(pricereg_year['ReleaseYear'], pricereg_year['PriceReg'] - 10, color = 'blue')
plt.show()

# %%
######## Histograms - When we want to check frequent values
plt.hist(sales['PriceReg'], bins = 20, color = 'blue')
#plt.hist(sales.loc[sales['LowNetPrice'] < 300, 'LowNetPrice'], bins = 100)
plt.show()

# %%
############Boxplots -  for univariate 
#plt.boxplot(sales['PriceReg'])
plt.figure(figsize = (10,10))
plt.boxplot(sales.loc[sales['PriceReg'] < 500, 'PriceReg'])
plt.show()

# %%
##############Scatter Plots - Two continuous Variables
#sales
#plt.figure(figsize = (10,10))
plt.scatter(sales['PriceReg'], sales['LowNetPrice'])
plt.show()

# %%
#Cool Feature
import seaborn as sns

new_sales = sales.drop(['Order', 'File_Type','SKU_number','SoldFlag','MarketingType','ReleaseNumber','New_Release_Flag', 'ReleaseYear','ItemCount'], axis=1)
new_sales.fillna(0, inplace =True)
sns.pairplot(new_sales)

# %%
#Heatmaps - co-occurence between two discrete variables+
f, ax = plt.subplots(figsize=(10, 8))
corr = new_sales.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
corr = new_sales.corr()

# %%
corr
# Out:
#                 SoldCount  StrengthFactor  PriceReg  LowUserPrice  LowNetPrice
# SoldCount        1.000000       -0.055257  0.046133      0.101096    -0.006842
# StrengthFactor  -0.055257        1.000000  0.033239      0.022484     0.055824
# PriceReg         0.046133        0.033239  1.000000      0.135210     0.117767
# LowUserPrice     0.101096        0.022484  0.135210      1.000000     0.045149
# LowNetPrice     -0.006842        0.055824  0.117767      0.045149     1.000000
