# %%
import numpy as np

# %%
a = np.linspace(10,0,20)
b = np.linspace(0,10,20)

# %%
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline  
# matplotlib.style.use('ggplot')

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ashwinku\\Documents\\training'

# %%
fig = plt.figure(figsize =(50,10))

ax1 = plt.subplot()

ax1.plot(a,b)

plt.savefig('lineplot_demo.png')
# plt.show()

# %%
box plot -- three line  mean  ---- 25th percentile  -- 75 percentile

# %%
inter quanitile range   ---- 75percentile + 1.5 * (75th percentile - 25th percenil)
25percentile - 1.5 * (75th percentile - 25th percenil)
